# %%
import numpy as np
from bs4 import BeautifulSoup
import requests
from requests import get
import pandas as pd
import numpy as np
import os
import time
import re
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
import prepare
import acquire 

print('Success')
# Out:
# Success

# %%
gitMDs = prepare.prep_gitMDs()
gitMDs
# Out:
#                                                   body  \
# 0    \n\n\n\n\nfreeCodeCamp.org's open-source codeb...
# 1    \n\n\n\n\n\n\n\n\n\n\nSupporting Vue.js\nVue.j...
# 2    React ·    \nReact is a JavaScript library for...
# 3    \n\n\n\n\nBootstrap\n\n  Sleek, intuitive, and...
# 4    Airbnb JavaScript Style Guide() {\nA mostly re...
# ..                                                 ...
# 214  \n\n\n\n    An Apache 2.0 NLP research library...
# 215  \n\n\n\n\nAbout\nWifiphisher is a rogue Access...
# 216  httpbin(1): HTTP Request & Response Service\nA...
# 217  一些非常有趣的python爬虫例子,对新手比较友好\n\n\n\n\n\n\n\n\n\n\...
# 218  mycli\n\n\n\nA command line client for MySQL t...
#
#                      top_code  \
# 0     \n\nJavaScript\n91.3%\n
# 1     \n\nJavaScript\n97.7%\n
# 2     \n\nJavaScript\n95.0%\n
# 3     \n\nJavaScript\n46.7%\n
# 4    \n\nJavaScript\n100.0%\n
# ..                        ...
# 214       \n\nPython\n97.6%\n
# 215       \n\nPython\n76.3%\n
# 216       \n\nPython\n74.6%\n
# 217       \n\nPython\n88.1%\n
# 218       \n\nPython\n98.0%\n
#
#                                                  clean top_code_clean  \
# 0    freecodecamporg ' opensource codebase curricul...     javascript
# 1    supporting vuejs vuejs mitlicensed open source...     javascript
# 2    react react javascript library building user i...     javascript
# 3    bootstrap sleek intuitive powerful frontend fr...     javascript
# 4    airbnb javascript style guide mostly reasonabl...     javascript
# ..                                                 ...            ...
# 214  apache 20 nlp research library built pytorch d...         python
# 215  wifiphisher rogue access point framework condu...         python
# 216  httpbin1 http request response service kenneth...         python
# 217  python python gitee 1 chrome chromechromedrive...         python
# 218  mycli command line client mysql autocompletion...         python
#
#      percentage
# 0          91.3
# 1          97.7
# 2          95.0
# 3          46.7
# 4         100.0
# ..          ...
# 214        97.6
# 215        76.3
# 216        74.6
# 217        88.1
# 218        98.0
#
# [219 rows x 5 columns]

# %%
gitMDs = gitMDs.drop_duplicates()
gitMDs['top_code_clean'].value_counts()
# Out:
# javascript    110
# python        109
# Name: top_code_clean, dtype: int64
